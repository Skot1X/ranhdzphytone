# %% [markdown]
# <a href="https://colab.research.google.com/github/Skot1X/ranhdzphytone/blob/main/DZ6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


df = pd.read_csv('web_clients_correct_доп материал к тема 6, 7.csv').head(15)
#df = pd.read_csv('web_clients_correct_доп материал к тема 6, 7.csv')

def age_group(age):
    if age > 25:
        return "Старше 25"
    else:
        return "Младше или равен 25"


df['age'] = df['age'].apply(age_group)


print(df['age'])
# Out:
# 0               Старше 25
# 1               Старше 25
# 2               Старше 25
# 3               Старше 25
# 4     Младше или равен 25
# 5               Старше 25
# 6               Старше 25
# 7               Старше 25
# 8               Старше 25
# 9               Старше 25
# 10              Старше 25
# 11              Старше 25
# 12    Младше или равен 25
# 13              Старше 25
# 14              Старше 25
# Name: age, dtype: object

# %%
import pandas as pd


df = pd.read_csv('web_clients_correct_доп материал к тема 6, 7.csv')

filtered = df[(df['sex'] == 'male') & (df['age'] > 30)]

print(filtered)
# Out:
#                                           name device_type            browser  \
# 1               Allison  Master. Hudson Trevor      tablet              Opera
# 5                          Anderson  Mr. Harry      mobile            Firefox
# 7                       Andrews  Mr. Thomas Jr      tablet  Internet Explorer
# 9                      Artagaveytia  Mr. Ramon      mobile            Firefox
# 10                      Astor  Col. John Jacob     desktop             Chrome
# ..                                         ...         ...                ...
# 900  Johnston  Master. William Arthur "Willie"     desktop             Chrome
# 902                     Johnston  Mr. Andrew G      tablet  Internet Explorer
# 905                          Jonsson  Mr. Carl     desktop            Firefox
# 909                        Jussila  Mr. Eiriik     desktop            Firefox
# 914          Karlsson  Mr. Julius Konrad Eugen      laptop              Opera
#
# ...
