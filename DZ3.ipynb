# %% [markdown]
# <a href="https://colab.research.google.com/github/Skot1X/ranhdzphytone/blob/main/DZ3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = "test"

length = len(word)

if length % 2 == 1:
    middle_index = length // 2
    print(word[middle_index])
else:

    middle_left = length // 2 - 1
    middle_right = length // 2
    print(word[middle_left:middle_right + 1])
# Out:
# es

# %%
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

if len(boys) != len(girls):
    print("Внимание, кто-то может остаться без пары!")
else:
    bsorted = sorted(boys)
    gsorted = sorted(girls)

    print("Идеальные пары:")
    for boy, girl in zip(bsorted, gsorted):
        print(f"{boy} и {girl}")
# Out:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
