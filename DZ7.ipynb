# %% [markdown]
# <a href="https://colab.research.google.com/github/Skot1X/ranhdzphytone/blob/main/DZ7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

df = pd.read_csv('web_clients_correct_доп материал к тема 6, 8.csv').head(15)

plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x='age', y='bill', s=80)
plt.title("Зависимость расходов от возраста (Seaborn)")
plt.show()

# %%
fig = px.scatter(df,
                 x='age',
                 y='bill',
                 size='bill',
                 title="Зависимость расходов от возраста (Plotly)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(7,5))
sns.regplot(data=df, x='age', y='bill')
plt.show()
